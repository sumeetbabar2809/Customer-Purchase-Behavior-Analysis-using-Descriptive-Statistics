# %% [markdown]
# <a href="https://colab.research.google.com/github/sumeetbabar2809/Customer-Purchase-Behavior-Analysis-using-Descriptive-Statistics/blob/main/Applied_Statistics_Project11_7_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# **Project Type** : Exploratory Data Analysis (EDA)
#
# **Contribution** : Individual

# %% [markdown]
# **Github** :

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %% [markdown]
# ## **Import libraries**

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/Assignments/superstore assignment/Superstore_Marketing_Data.csv')
data.T #transpose the data
# Out:
#                            0           1           2           3     \
# Id                         1826           1       10476        1386
# Year_Birth                 1970        1961        1958        1967
# Education            Graduation  Graduation  Graduation  Graduation
# Marital_Status         Divorced      Single     Married    Together
# Income                  84835.0     57091.0     67267.0     32474.0
# Kidhome                       0           0           0           1
# Teenhome                      0           0           1           1
# Dt_Customer           6/16/2014   6/15/2014   5/13/2014    ########
# Recency                       0           0           0           0
# MntWines                    189         464         134          10
# MntFruits                   104           5          11           0
# MntMeatProducts             379          64          59           1
# MntFishProducts             111           7          15           0
# ...

# %%
data.shape
# Out:
# (2240, 22)

# %% [markdown]
# * The dataset has a shape of 2,240 rows and 22 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
#checking null vales
data.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %% [markdown]
# * Out of the 2,240 records in the Income dataset, 24 records contain null values. Since the number of null values is relatively small, we will not drop these records. Instead, it is necessary to calculate the average income and use this value to impute the missing data.

# %%
#Checking duplicates
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * The dataset has zero duplicate values.

# %% [markdown]
# ## **Missing Null/Nan values**

# %% [markdown]
# **Income :**

# %%
#Filling null values in 'Income' column with the mean
data['Income'].fillna(data['Income'].mean(), inplace=True); data.isnull().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %% [markdown]
# #### **Dt_Customer :**

# %% [markdown]
# Identify the Issue:
#
# 1.Check the number of corrupted entries.
#
# 2.Convert to Datetime Format:
# Convert the Dt_Customer column to a datetime format, coercing errors to NaT (Not a Time).
#
# 3.Forward Fill Missing Values:
# Fill the missing values using the forward fill method.

# %%
data['Dt_Customer'].str.contains('########').sum()
# Out:
# 916

# %%
#to datetime format
data['Dt_Customer'] = pd.to_datetime(data['Dt_Customer'], errors='coerce')

# %%
data['Dt_Customer'].fillna(method='ffill', inplace=True)

# %%
sns.histplot(data['Dt_Customer'],kde = True)
sns.set(rc={'figure.figsize':(10,10)})
plt.show()

# %% [markdown]
# * A histogram is created to visualize the distribution of the Dt_Customer column, allowing us to see patterns and trends in customer enrollment over time. The kernel density estimate (kde) provides a smooth curve representing the data distribution.
#
# * By following these steps, we address the issue of corrupted data in the Dt_Customer column, ensuring it is in a usable format for analysis and visualization.

# %% [markdown]
# * With the cleaned data, we can now analyze the distribution of customer demographics. This analysis will help us understand the characteristics of our customer base, such as age, education, marital status, and other relevant demographic information.

# %%
plt.figure(figsize=(20, 10))

# Plot 1: Age Distribution
plt.subplot(2, 2, 1)
sns.histplot(data['Year_Birth'], kde=True)
plt.title('Distribution of Customer Age')
plt.xlabel('Year of Birth')
plt.ylabel('Count')

# Plot 2: Education Distribution
plt.subplot(2, 2, 2)
education_counts = data['Education'].value_counts()
sns.countplot(data['Education'], order=education_counts.index)
plt.title('Distribution of Customer Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Plot 3: Marital Status Distribution
plt.subplot(2, 2, 3)
marital_counts = data['Marital_Status'].value_counts()
colors = sns.color_palette('pastel')[0:len(marital_counts)]
bars = plt.barh(marital_counts.index, marital_counts.values, color=colors)
for bar in bars:
    plt.text(bar.get_width() + 20, bar.get_y() + bar.get_height()/2, f'{bar.get_width()/sum(marital_counts.values)*100:.1f}%',
             va='center', ha='left', fontsize=11, weight='bold')
plt.xlabel('Count')
plt.title('Distribution of Customer Marital Status')

# Plot 4: Income Distribution
plt.subplot(2, 2, 4)
sns.histplot(data['Income'], kde=True)
plt.title('Distribution of Customer Income')
plt.xlabel('Income')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Age Distribution:**
#
# **Histogram** helps to understand the spread and central tendency of customer ages, identifying common age ranges and potential outliers.
#
# The distribution of customer age shows a peak around certain birth years, suggesting a concentration of customers within specific age groups. Further analysis could explore demographic trends or age-related preferences.
#
# **Education Distribution:**
#
# **Countplot** clearly displays the number of customers in each education level category, making it easy to identify the predominant education levels among customers.
#
# The majority of customers have completed higher education (e.g., Graduate or master's degree), as indicated by the count of customers in each education level category. This suggests a well-educated customer base.
#
# **Marital Status Distribution:**
#
# **Horizontal Bar chart** provides a quick overview of the distribution of marital statuses among customers, highlighting the most prevalent statuses and allowing for easy comparison.
#
# Most customers are married or living together (as per the marital status distribution). This demographic insight could influence marketing strategies or product offerings tailored to family-oriented consumers.
#
# **Income Distribution:**
#
# **Histogram** helps in understanding the income distribution pattern, identifying income groups that may influence purchasing power and marketing strategies.
#
# The income distribution of customers shows varying levels, with a significant portion potentially falling into higher income brackets. Understanding income distribution helps in targeting products or services aligned with different purchasing power segments.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %% [markdown]
# ## **Understanding your variable**

# %%
data.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35538.750000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51741.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68289.750000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
# std     3246.662198    11.984069   25037.797168     0.538398     0.544538
#
#                          Dt_Customer      Recency     MntWines    MntFruits  \
# count                           2240  2240.000000  2240.000000  2240.000000
# mean   2013-07-17 02:02:47.142857216    49.109375   303.935714    26.302232
# ...

# %%
key_variables = ['Id', 'Year_Birth', 'Income', 'Kidhome', 'Teenhome',
                 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts',
                 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds',
                 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
                 'NumStorePurchases', 'NumWebVisitsMonth', 'Response', 'Complain']

# Calculate mean, median, and mode for selected columns
mean_values = data[key_variables].mean()
median_values = data[key_variables].median()
mode_values = data[key_variables].mode().iloc[0]

# Create a summary DataFrame
summary_data = pd.DataFrame({
    'Mean': mean_values,
    'Median': median_values,
    'Mode': mode_values
})

# Print the summary DataFrame
print(summary_data)
# Out:
#                              Mean   Median          Mode
# Id                    5592.159821   5458.5      0.000000
# Year_Birth            1968.805804   1970.0   1976.000000
# Income               52247.251354  51741.5  52247.251354
# Kidhome                  0.444196      0.0      0.000000
# Teenhome                 0.506250      0.0      0.000000
# Recency                 49.109375     49.0     56.000000
# MntWines               303.935714    173.5      2.000000
# MntFruits               26.302232      8.0      0.000000
# MntMeatProducts        166.950000     67.0      7.000000
# MntFishProducts         37.525446     12.0      0.000000
# MntSweetProducts        27.062946      8.0      0.000000
# MntGoldProds            44.021875     24.0      1.000000
# NumDealsPurchases        2.325000      2.0      1.000000
# NumWebPurchases          4.084821      4.0      2.000000
# NumCatalogPurchases      2.662054      2.0      0.000000
# ...

# %% [markdown]
# **1.Demographics:**
#
# **Year of Birth:** On average, customers were born around 1969. The most common birth year is 1976.
#
# **Income:** The average income is about 52.247 dollars.Many customers have this income, with a median income of around 51,742 dollars.
#
# **2.Household Composition:**
#
# **Kids and Teens:** Most households have less than one child (average 0.44) and about one teenager (average 0.51). Many households have no children or teenagers.
#
# **3.Recency:**
# Customers typically made their last purchase about 49 days ago, showing consistent buying habits.
#
# **4.Spending Habits:**
#
# **Wines:** Customers spend the most on wines, averaging 303.94 dollars. However, the typical spending is lower at 173.5 dollars, with many spending as little as 2 dollars.
#
# **Other Products:** Average spending is 166.95 dollars on meat, 37.53 dollars on fish, 27.06 dollars on sweets, and 44.02 dollars on gold products. Median spending is lower, with many not spending on these items at all.
# Fruits: Customers spend an average of 26.30 dollars on fruits, but many do not buy fruits.
#
# **5.Purchase Channels:**
#
# **Deals and Web Purchases:** Customers take advantage of deals about 2.33 times and make 4.08 web purchases on average. Many customers make one deal purchase and two web purchases.
#
# **Catalog and Store Purchases:** Customers make fewer catalog purchases (average 2.66) but more store purchases (average 5.79). The most common number of store purchases is three.
#
# **Web Visits:** Customers visit the website about 5.32 times a month on average, with many visiting seven times.
#
# **6.Customer Engagement:**
#
# **Campaign Response:** Very few customers respond to marketing campaigns (average 0.15 responses).
#
# **Complaints:** Hardly any customers file complaints, indicating low complaint rates.
#
# ##**Insights**
# There are a few high spenders that increase the average spending in many categories.
# Most households do not have children or teenagers, which can influence marketing strategies.
# Customers prefer online shopping and in-store purchases, suggesting opportunities for digital and in-store promotions.
# The low response to campaigns might indicate either customer satisfaction or lack of engagement, which needs further investigation.
# This analysis helps understand customer demographics, spending habits, and engagement, which can be used to improve marketing and customer service strategies.

# %%
key_variables = ['Id', 'Year_Birth', 'Income', 'Kidhome', 'Teenhome',
                 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts',
                 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds',
                 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
                 'NumStorePurchases', 'NumWebVisitsMonth', 'Response', 'Complain']
# Create a summary DataFrame
summary_data = pd.DataFrame({
    'Variance': data[key_variables].var(),
    'Standard Deviation': data[key_variables].std()
})

# Print the summary DataFrame
print(summary_data)
# Out:
#                          Variance  Standard Deviation
# Id                   1.054082e+07         3246.662198
# Year_Birth           1.436179e+02           11.984069
# Income               6.268913e+08        25037.797168
# Kidhome              2.898725e-01            0.538398
# Teenhome             2.965219e-01            0.544538
# Recency              8.388237e+02           28.962453
# MntWines             1.132978e+05          336.597393
# MntFruits            1.581926e+03           39.773434
# MntMeatProducts      5.094743e+04          225.715373
# MntFishProducts      2.984325e+03           54.628979
# MntSweetProducts     1.704080e+03           41.280498
# MntGoldProds         2.721442e+03           52.167439
# NumDealsPurchases    3.733542e+00            1.932238
# NumWebPurchases      7.721252e+00            2.778714
# NumCatalogPurchases  8.544517e+00            2.923101
# NumStorePurchases    1.056873e+01            3.250958
# ...

# %%
key_variables = ['Income', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
                 'NumDealsPurchases', 'MntGoldProds', 'NumWebPurchases', 'NumWebVisitsMonth']
# Set up the plot grid
num_vars = len(key_variables)
num_cols = 3
num_rows = (num_vars + num_cols - 1) // num_cols  # Calculate number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 4*num_rows))

# Loop through each key variable to create boxplots
for i, variable in enumerate(key_variables):
    row = i // num_cols
    col = i % num_cols
    sns.boxplot(y=data[variable], ax=axes[row, col])
    axes[row, col].set_title(f'Boxplot of {variable}')
    axes[row, col].set_xlabel('')
    axes[row, col].set_ylabel('')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ##**Understanding Outliers in Customer Data**
#
# In the boxplots for Income, Recency, and various spending categories (like on wines, fruits, meats, fish, and gold products), along with metrics like deals and web purchases, some data points might seem far from the others. These are called outliers.
#
# These outliers aren't mistakes. They're actually normal because they reflect real differences in how much people earn and spend. For example, high incomes or big spending on products can lead to these outliers. So, instead of ignoring them, we see them as part of how customers behave and how incomes vary.

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %%
total_purchases = lambda data: data[['NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']].sum(axis=1)

# Lambda function to calculate expected_purchases
expected_purchases = lambda data: total_purchases(data).mean()
# Calculating p_purchase in one line using lambda and method chaining
probab_purchase = (lambda data: total_purchases(data).mean() / total_purchases(data).max())(data)

from scipy.stats import norm
x_income, y_income = data['Income'].mean(), data['Income'].std()
prob_income_gt_70000 = 1 - norm.cdf(70000, x_income, y_income)
expected_income = x_income + y_income * norm.ppf(prob_income_gt_70000)



# Printing results
print(f"Expected Purchases: {expected_purchases(data):.2f}")
print(f"Probability of Purchase: {probab_purchase:.4f}")
print("-"*180)

print(f"Probability of income > $70,000: {prob_income_gt_70000:.4f}")
print(f"Expected income: {expected_income:.2f}")
# Out:
# Expected Purchases: 14.86
# Probability of Purchase: 0.3378
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Probability of income > $70,000: 0.2392
# Expected income: 34494.50

# %% [markdown]
# **Expected Purchases:** Customers are expected to make an average of 14.86 purchases across different categories.
#
# **Probability of Purchase:** There's a 33.78% likelihood that customers will make a purchase based on historical data.
#
# **Probability of Income > 70,000 dollars:** Approximately 23.92% of individuals in the dataset have an income greater than 70,000 dollars.
#
# **Expected Income:** The average estimated income for individuals in the dataset is 34,494.50 dollars.
#
#
# These insights inform strategies for marketing, customer segmentation, and operational planning based on customer behavior and income distribution.

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %%
# Calculate TotalSpend as the sum of various purchase types
data['TotalSpend'] = data[['NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']].sum(axis=1)

# Plotting with Seaborn using an orange gradient
plt.figure(figsize=(15, 5))
sns.scatterplot(x='Income', y='TotalSpend', data=data, hue='Income', color='Red', legend=True)
plt.title('Relationship between Income and Total Spending')
plt.xlabel('Income')
plt.ylabel('Total Spending')
plt.show()

# %% [markdown]
# **Relationship between Income and Total Spending:**
#
# * The scatter plot illustrates the relationship between income levels (**Income**) and total spending (**Total Spending**).
# *Higher income levels are represented by darker shades of orange in the plot, reflecting increased total spending.
# *This visualization provides insights into how income influences spending behavior across various purchase categories in your dataset.

# %%
numerical_cols = data.select_dtypes(include=['number']).columns

# Calculate correlation matrix for numerical columns
correlation_matrix = data[numerical_cols].corr()

# Visualize correlation matrix using a heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %% [markdown]
# * This Heatmap technique helps in identifying and interpreting relationships and dependencies among numerical variables in the dataset, aiding in data exploration and analysis.

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Education', y='TotalSpend', data=data, color = 'orange')
plt.title('Spending Habits across Different Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Total Spending')
plt.show()

# %% [markdown]
# Customers with a 'PhD' education level spend more on average compared to other education levels, as indicated by the analysis of total spending across different educational backgrounds using a bar plot.
#
# ##**Recommendations:**
#
# **Target Marketing Efforts:**\
# Direct marketing campaigns towards customers with PhD education levels, focusing on products and services that align with their higher spending habits.
#
# **Personalized Engagement:**\
# Offer personalized recommendations and exclusive benefits tailored to customers with higher educational achievements to enhance their shopping experience.
#
# **Product Strategy:**\
# Introduce premium products or services that appeal to customers with PhDs, ensuring your offerings meet their preferences and lifestyle choices.
#
# **Strategic Partnerships:**\
# Collaborate with educational institutions or professional associations catering to individuals with PhD qualifications to expand brand reach and credibility within this demographic.
#
# **Continuous Analysis:**\
# Regularly analyze spending trends across different education levels to adapt strategies and optimize marketing efforts effectively.

# %%
plt.figure(figsize=(12, 6))
sns.histplot(x='Marital_Status', y='TotalSpend', data=data,color ='Red')
plt.title('Spending habits across different marital statuses')
plt.xlabel('Marital Status')
plt.ylabel('Total Spending')
plt.show()

# %% [markdown]
# The histogram plot illustrates that customers who are married tend to have higher spending habits compared to other marital statuses. This insight was derived from analyzing total spending across different marital statuses using a histogram.
#
# ##**Recommendations:**
# **Targeted Marketing Strategies:**
# Develop targeted marketing campaigns that appeal specifically to married customers. Highlight products and services that cater to their spending habits and household needs.
#
# **Customer Loyalty Programs:**
# Implement loyalty programs or special offers aimed at married couples to encourage repeat purchases and foster brand loyalty.
#
# **Product Bundling:**
# Create product bundles or packages that are attractive to married customers, offering convenience and value for their spending preferences.
#
# **Enhanced Customer Experience:**
# Provide personalized shopping experiences and customer service initiatives that cater to the needs and preferences of married customers.
#
# **Data Utilization:**
# Continuously analyze data on spending habits among different marital statuses to refine marketing strategies and optimize business decisions effectively.
#
# By implementing these recommendations, businesses can capitalize on the higher spending tendencies of married customers, enhancing customer satisfaction and driving revenue growth in targeted market segments.

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
